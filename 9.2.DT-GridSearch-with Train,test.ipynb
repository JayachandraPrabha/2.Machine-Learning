# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor 
grid_params={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
             'splitter':['best','random'],
             'max_features':['None','sqrt','log2','auto']
            }
grid=GridSearchCV(DecisionTreeRegressor(),grid_params,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 40 fits failed out of a total of 160.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt', 'auto' (deprecated)} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 31 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'auto' (deprecated), 'sqrt', 'log2'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.67547734 0.55091126 0.59783886 0.57388758
#  0.67833653 0.66489895        nan        nan 0.66865635 0.58698888
#  0.62305355 0.63357008 0.67636998 0.63066289        nan        nan
#  0.55139219 0.59653757 0.62663537 0.59548337 0.6592881  0.67809474
#         nan        nan 0.68751554 0.58311691 0.67796912 0.62695114
#  0.68696351 0.64278746]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['None', 'sqrt', 'log2', 'auto'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_
# result
print("result is {}".format(grid.best_params_))
# Out:
# result is {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002799      0.000399         0.000000    0.000000e+00
# 1        0.002798      0.000399         0.000000    0.000000e+00
# 2        0.011590      0.005710         0.005198    2.711224e-03
# 3        0.005995      0.000633         0.002999    7.008046e-07
# 4        0.006994      0.000632         0.009196    1.095475e-02
# 5        0.006594      0.000490         0.003799    1.599216e-03
# 6        0.042771      0.000979         0.003799    3.997566e-04
# 7        0.089743      0.097050         0.003199    3.998280e-04
# 8        0.001599      0.000489         0.000000    0.000000e+00
# 9        0.000999      0.000001         0.000000    0.000000e+00
# 10       0.013590      0.012200         0.003400    4.909349e-04
# 11       0.006796      0.000400         0.009195    1.140113e-02
# 12       0.007595      0.000491         0.003799    1.166204e-03
# 13       0.019588      0.015973         0.018391    1.377174e-02
# 14       0.117327      0.097233         0.008196    7.467362e-04
# 15       0.107734      0.088954         0.007797    7.472198e-04
# 16       0.002598      0.000490         0.000000    0.000000e+00
# 17       0.009396      0.012298         0.000000    0.000000e+00
# 18       0.129921      0.015648         0.007796    3.997333e-04
# 19       0.066359      0.008354         0.016391    1.629444e-02
# 20       0.054165      0.037889         0.003999    1.546958e-03
# 21       0.027183      0.006010         0.002799    4.000430e-04
# 22       0.093144      0.008993         0.003199    3.998049e-04
# 23       0.083749      0.012568         0.016192    1.575741e-02
# 24       0.001000      0.000001         0.000000    0.000000e+00
# 25       0.001002      0.000003         0.000000    0.000000e+00
# 26       0.010392      0.001959         0.003399    4.901935e-04
# 27       0.014191      0.013398         0.003399    8.000136e-04
# 28       0.019387      0.012760         0.003199    3.996384e-04
# 29       0.012392      0.004754         0.005199    1.939561e-03
# 30       0.107334      0.055787         0.015193    9.276036e-03
# 31       0.083348      0.053800         0.007997    6.315820e-04
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6    squared_error               auto           best
# 7    squared_error               auto         random
# 8     friedman_mse               None           best
# 9     friedman_mse               None         random
# 10    friedman_mse               sqrt           best
# 11    friedman_mse               sqrt         random
# 12    friedman_mse               log2           best
# 13    friedman_mse               log2         random
# 14    friedman_mse               auto           best
# 15    friedman_mse               auto         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18  absolute_error               sqrt           best
# 19  absolute_error               sqrt         random
# 20  absolute_error               log2           best
# 21  absolute_error               log2         random
# 22  absolute_error               auto           best
# 23  absolute_error               auto         random
# 24         poisson               None           best
# 25         poisson               None         random
# 26         poisson               sqrt           best
# 27         poisson               sqrt         random
# 28         poisson               log2           best
# 29         poisson               log2         random
# 30         poisson               auto           best
# 31         poisson               auto         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.717514
# 3   {'criterion': 'squared_error', 'max_features':...           0.741289
# 4   {'criterion': 'squared_error', 'max_features':...           0.743525
# 5   {'criterion': 'squared_error', 'max_features':...           0.679341
# 6   {'criterion': 'squared_error', 'max_features':...           0.726319
# 7   {'criterion': 'squared_error', 'max_features':...           0.625268
# 8   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 9   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.776896
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.533285
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.698190
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.685257
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.726370
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.686040
# 16  {'criterion': 'absolute_error', 'max_features'...                NaN
# 17  {'criterion': 'absolute_error', 'max_features'...                NaN
# 18  {'criterion': 'absolute_error', 'max_features'...           0.706236
# 19  {'criterion': 'absolute_error', 'max_features'...           0.644567
# 20  {'criterion': 'absolute_error', 'max_features'...           0.756103
# 21  {'criterion': 'absolute_error', 'max_features'...           0.581018
# 22  {'criterion': 'absolute_error', 'max_features'...           0.784484
# 23  {'criterion': 'absolute_error', 'max_features'...           0.714526
# 24  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 25  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 26  {'criterion': 'poisson', 'max_features': 'sqrt...           0.762936
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...           0.640243
# 28  {'criterion': 'poisson', 'max_features': 'log2...           0.770404
# 29  {'criterion': 'poisson', 'max_features': 'log2...           0.555085
# 30  {'criterion': 'poisson', 'max_features': 'auto...           0.759768
# 31  {'criterion': 'poisson', 'max_features': 'auto...           0.714484
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.676066           0.653912           0.687333
# 3            0.388095           0.464075           0.666966
# 4            0.680933           0.520118           0.436693
# 5            0.619121           0.641164           0.518223
# 6            0.682216           0.595070           0.667148
# 7            0.634023           0.734365           0.730138
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10           0.678807           0.522210           0.725130
# 11           0.620538           0.542649           0.643683
# 12           0.705369           0.565868           0.615121
# 13           0.671428           0.601325           0.590990
# 14           0.679984           0.626048           0.663696
# 15           0.637537           0.580312           0.657020
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.500241           0.438156           0.489226
# 19           0.696032           0.481065           0.602359
# 20           0.571384           0.584068           0.654596
# 21           0.600744           0.636804           0.620602
# 22           0.667409           0.610038           0.609785
# 23           0.645066           0.678335           0.691250
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.689458           0.664794           0.702234
# 27           0.539748           0.563582           0.573828
# 28           0.748231           0.517061           0.709921
# 29           0.745071           0.518658           0.639975
# 30           0.695586           0.616727           0.679725
# 31           0.584755           0.584455           0.666744
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               25
# 1                 NaN              NaN             NaN               25
# 2            0.642562         0.675477        0.026293                7
# 3            0.494131         0.550911        0.131899               24
# 4            0.607925         0.597839        0.109763               17
# 5            0.411589         0.573888        0.097090               22
# 6            0.720931         0.678337        0.047308                3
# 7            0.600701         0.664899        0.056084                9
# 8                 NaN              NaN             NaN               25
# 9                 NaN              NaN             NaN               25
# 10           0.640239         0.668656        0.086328                8
# 11           0.594789         0.586989        0.043013               20
# 12           0.530720         0.623054        0.069685               16
# 13           0.618851         0.633570        0.037879               12
# 14           0.685753         0.676370        0.032539                6
# 15           0.592404         0.630663        0.039516               13
# 16                NaN              NaN             NaN               25
# 17                NaN              NaN             NaN               25
# 18           0.623102         0.551392        0.098410               23
# 19           0.558665         0.596538        0.073496               18
# 20           0.567026         0.626635        0.072058               15
# 21           0.538249         0.595483        0.034208               19
# 22           0.624725         0.659288        0.066046               10
# 23           0.661298         0.678095        0.023972                4
# 24                NaN              NaN             NaN               25
# 25                NaN              NaN             NaN               25
# 26           0.618156         0.687516        0.047404                1
# 27           0.598183         0.583117        0.034173               21
# 28           0.644229         0.677969        0.091139                5
# 29           0.675967         0.626951        0.081751               14
# 30           0.683011         0.686964        0.045555                2
# 31           0.663500         0.642787        0.050821               11

# %%
'age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'
age=int(input("Enter the Age: "))
bmi=int(input("Enter the BMI_range: "))
children=int(input("Enter the Children_count: "))
sex_male=int(input("Enter the sex, male 1/female 0: "))
smoker_yes=int(input("Enter the smoker, yes 1/no 0): "))

pred=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Prediction is: {}".format(pred))
# Out:
# Enter the Age: 44
# Enter the BMI_range: 32
# Enter the Children_count: 2
# Enter the sex, male 1/female 0: 1
# Enter the smoker, yes 1/no 0): 1
# Prediction is: [48549.17835]
