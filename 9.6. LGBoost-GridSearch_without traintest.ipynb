# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(independent,dependent,test_size=0.20,random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
# x_test=sc.transform(x_test)

# %%
import lightgbm as lgb
from lightgbm import LGBMRegressor

# %%
from sklearn.model_selection import GridSearchCV
grid_params= {"learning_rate":[1,10,50],
             "n_estimators":[10,50],
              "max_depth":[3,5,9]
             }
grid=GridSearchCV(LGBMRegressor(),grid_params,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [1, 10, 50], 'max_depth': [3, 5, 9],
#                          'n_estimators': [10, 50]},
#              verbose=3)

# %%
# from sklearn.model_selection import GridSearchCV
# grid_params= {"learning_rate":[1,10,50],
#              "n_estimators":[10,50,100,1000],
#               "max_depth":[3,5,9],
#               "subsample":[0.3,0.5,0.9],
#               "colsample_bytree":[0.3,0.7,0.9],
#               "min_child_samples":[3,6,9]
#              }

# %%
grid=GridSearchCV(LGBMRegressor(),grid_params,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [1, 10, 50], 'max_depth': [3, 5, 9],
#                          'n_estimators': [10, 50]},
#              verbose=3)

# %%
result=grid.cv_results_
print("The resut is:{}".format(grid.best_params_))
# Out:
# The resut is:{'learning_rate': 1, 'max_depth': 3, 'n_estimators': 10}

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012191      0.001469         0.005996        0.001414
# 1        0.019188      0.000747         0.005596        0.001200
# 2        0.011792      0.001327         0.009195        0.008419
# 3        0.031379      0.005813         0.005397        0.000489
# 4        0.015790      0.003653         0.004397        0.000491
# 5        0.041773      0.003967         0.007596        0.001854
# 6        0.010393      0.000489         0.005397        0.001959
# 7        0.017188      0.000400         0.006597        0.004713
# 8        0.012391      0.000490         0.004599        0.000490
# 9        0.026982      0.001095         0.004599        0.000489
# 10       0.014391      0.000799         0.004197        0.000401
# 11       0.033179      0.000400         0.004799        0.000400
# 12       0.009794      0.000748         0.004597        0.000489
# 13       0.013990      0.000001         0.005397        0.001356
# 14       0.014791      0.001468         0.004198        0.000400
# 15       0.020986      0.001094         0.004397        0.000490
# 16       0.015590      0.001199         0.004197        0.000400
# 17       0.027182      0.001599         0.004797        0.000749
#
#    param_learning_rate param_max_depth param_n_estimators  \
# 0                    1               3                 10
# 1                    1               3                 50
# 2                    1               5                 10
# 3                    1               5                 50
# 4                    1               9                 10
# 5                    1               9                 50
# 6                   10               3                 10
# 7                   10               3                 50
# 8                   10               5                 10
# 9                   10               5                 50
# 10                  10               9                 10
# 11                  10               9                 50
# 12                  50               3                 10
# 13                  50               3                 50
# 14                  50               5                 10
# 15                  50               5                 50
# 16                  50               9                 10
# 17                  50               9                 50
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 1, 'max_depth': 3, 'n_estima...       8.675183e-01
# 1   {'learning_rate': 1, 'max_depth': 3, 'n_estima...       8.436052e-01
# 2   {'learning_rate': 1, 'max_depth': 5, 'n_estima...       8.505959e-01
# 3   {'learning_rate': 1, 'max_depth': 5, 'n_estima...       8.225020e-01
# 4   {'learning_rate': 1, 'max_depth': 9, 'n_estima...       8.243686e-01
# 5   {'learning_rate': 1, 'max_depth': 9, 'n_estima...       7.911434e-01
# 6   {'learning_rate': 10, 'max_depth': 3, 'n_estim...      -1.072148e+19
# 7   {'learning_rate': 10, 'max_depth': 3, 'n_estim...      -4.475743e+68
# 8   {'learning_rate': 10, 'max_depth': 5, 'n_estim...      -1.154362e+19
# 9   {'learning_rate': 10, 'max_depth': 5, 'n_estim...      -4.818952e+68
# 10  {'learning_rate': 10, 'max_depth': 9, 'n_estim...      -1.158150e+19
# 11  {'learning_rate': 10, 'max_depth': 9, 'n_estim...      -4.834764e+68
# 12  {'learning_rate': 50, 'max_depth': 3, 'n_estim...      -5.614694e+33
# 13  {'learning_rate': 50, 'max_depth': 3, 'n_estim...      -8.583015e+70
# 14  {'learning_rate': 50, 'max_depth': 5, 'n_estim...      -6.045052e+33
# 15  {'learning_rate': 50, 'max_depth': 5, 'n_estim...      -9.240891e+70
# 16  {'learning_rate': 50, 'max_depth': 9, 'n_estim...      -6.062182e+33
# 17  {'learning_rate': 50, 'max_depth': 9, 'n_estim...      -9.267076e+70
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0        7.829193e-01       8.836010e-01       8.402624e-01
# 1        7.647805e-01       8.579055e-01       8.303100e-01
# 2        7.786784e-01       8.570745e-01       8.176134e-01
# 3        7.444037e-01       8.301254e-01       8.091433e-01
# 4        7.563326e-01       8.448196e-01       8.123602e-01
# 5        7.198542e-01       7.957571e-01       7.860143e-01
# 6       -1.041286e+19      -9.459603e+18      -1.099089e+19
# 7       -4.346907e+68      -3.948966e+68      -4.588209e+68
# 8       -1.080518e+19      -9.498471e+18      -1.095346e+19
# 9       -4.510685e+68      -3.965192e+68      -4.572584e+68
# 10      -1.086574e+19      -9.656052e+18      -1.101464e+19
# 11      -4.535966e+68      -4.030975e+68      -4.598127e+68
# 12      -5.453072e+33      -4.953867e+33      -5.755779e+33
# 13      -8.335946e+70      -7.572826e+70      -8.798688e+70
# 14      -5.659522e+33      -4.974222e+33      -5.736177e+33
# 15      -8.651541e+70      -7.603944e+70      -8.768723e+70
# 16      -5.691811e+33      -5.060763e+33      -5.789256e+33
# 17      -8.700900e+70      -7.736238e+70      -8.849864e+70
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0        8.442297e-01     8.437062e-01    3.425142e-02                1
# 1        8.192949e-01     8.231792e-01    3.193581e-02                3
# 2        8.432126e-01     8.294350e-01    2.869681e-02                2
# 3        8.074343e-01     8.027218e-01    3.035344e-02                5
# 4        8.115507e-01     8.098863e-01    2.934947e-02                4
# 5        7.656362e-01     7.716810e-01    2.787991e-02                6
# 6       -9.992212e+18    -1.031541e+19    5.417597e+17                7
# 7       -4.171306e+68    -4.306226e+68    2.261611e+67               13
# 8       -1.014320e+19    -1.058879e+19    7.041101e+17                8
# 9       -4.234338e+68    -4.420350e+68    2.939349e+67               14
# 10      -1.010016e+19    -1.064362e+19    6.837029e+17                9
# 11      -4.216371e+68    -4.443240e+68    2.854158e+67               15
# 12      -5.232786e+33    -5.402040e+33    2.837122e+32               10
# 13      -7.999203e+70    -8.257936e+70    4.337034e+69               16
# 14      -5.311972e+33    -5.545389e+33    3.687290e+32               11
# 15      -8.120253e+70    -8.477070e+70    5.636650e+69               17
# 16      -5.298046e+33    -5.580412e+33    3.571815e+32               12
# 17      -8.098964e+70    -8.530608e+70    5.460127e+69               18

# %%
'age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'
age=int(input("Enter the Age: "))
bmi=int(input("Enter the BMI_range: "))
children=int(input("Enter the Children_count: "))
sex_male=int(input("Enter the sex, male 1/female 0: "))
smoker_yes=int(input("Enter the smoker, yes 1/no 0): "))

pred=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Prediction is: {}".format(pred))
# Out:
# Enter the Age: 34
# Enter the BMI_range: 23
# Enter the Children_count: 1
# Enter the sex, male 1/female 0: 1
# Enter the smoker, yes 1/no 0): 1
# Prediction is: [20043.12351531]
