# %%
import pandas as pd

# %%
data=pd.read_csv("Social_Network_Ads.csv")
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data=pd.get_dummies(data,drop_first=True)
data
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
data=data.drop('User ID',axis=1)
data
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
data['Purchased'].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
data.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
independent=data[['Age', 'EstimatedSalary','Gender_Male']]
dependent=data[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.20, random_state=0)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import GammaRegressor
regressor=GammaRegressor(solver='lbfgs',alpha=100)
regressor.fit(x_train,y_train)
# solver{‘lbfgs’, ‘newton-cholesky’}
# Out:
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 from sklearn.linear_model import GammaRegressor
#       2 regressor=GammaRegressor(solver='lbfgs',alpha=100)
# ----> 3 regressor.fit(x_train,y_train)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:226, in _GeneralizedLinearRegressor.fit(self, X, y, sample_weight)
#     220 linear_loss = LinearModelLoss(
#     221     base_loss=self._base_loss,
#     222     fit_intercept=self.fit_intercept,
#     223 )
#     225 if not linear_loss.base_loss.in_y_true_range(y):
# --> 226     raise ValueError(
#     227         "Some value(s) of y are out of the valid range of the loss"
#     228         f" {self._base_loss.__class__.__name__!r}."
#     229     )
#     231 # TODO: if alpha=0 check that X is not rank deficient
#     232
#     233 # IMPORTANT NOTE: Rescaling of sample_weight:
#    (...)
#     241 #     obj = sum(sample_weight * loss) + 1/2 * alpha * L2.
#     242 # Note that LinearModelLoss.loss() computes sum(sample_weight * loss).
#     243 sample_weight = sample_weight / sample_weight.sum()
#
# ValueError: Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.

# %%
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
