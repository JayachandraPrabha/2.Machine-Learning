# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
grid_params={'n_estimators':[10,50,100],
             'learning_rate':[10,50],
             'loss':['linear','square','exponential']
            }
grid=GridSearchCV(AdaBoostRegressor(),grid_params,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [10, 50],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
result=grid.cv_results_
# result
print("result is {}".format(grid.best_params_))
# Out:
# result is {'learning_rate': 10, 'loss': 'exponential', 'n_estimators': 10}

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.052767      0.012632         0.006596    7.992865e-04
# 1        0.186085      0.011190         0.014192    1.469295e-03
# 2        0.361977      0.031084         0.034579    1.455944e-02
# 3        2.294788      0.695442         0.144312    7.876124e-02
# 4        0.039975      0.000894         0.004998    9.416779e-07
# 5        0.171094      0.000401         0.012393    4.894739e-04
# 6        0.881857      0.039221         0.066959    9.523524e-03
# 7        2.112299      0.739678         0.108734    1.719570e-03
# 8        0.092344      0.027446         0.011993    3.030619e-03
# 9        0.465313      0.016466         0.031381    9.216089e-03
# 10       0.366174      0.023974         0.023186    4.003529e-04
# 11       2.483471      0.925601         0.111131    3.653324e-03
# 12       0.039175      0.000979         0.005198    4.000669e-04
# 13       0.168495      0.001854         0.012993    6.318822e-04
# 14       0.338591      0.004994         0.023187    7.479332e-04
# 15       2.340560      0.737343         0.156104    7.069922e-02
# 16       0.040375      0.001199         0.005196    4.003287e-04
# 17       0.173293      0.002938         0.013792    3.996613e-04
# 18       0.700169      0.201188         0.054966    1.450929e-02
# 19       2.372340      0.697695         0.110933    1.169032e-02
# 20       0.106734      0.001325         0.013991    1.094800e-03
# 21       0.435330      0.059347         0.030381    9.215760e-03
# 22       0.345588      0.003122         0.023186    3.998288e-04
# 23       2.641975      0.528987         0.236055    9.273425e-02
# 24       0.049169      0.006427         0.008595    3.379815e-03
# 25       0.221063      0.045953         0.015391    2.243128e-03
# 26       0.953413      0.292913         0.097539    7.292018e-02
# 27       2.831457      0.691978         0.124324    2.321202e-02
# 28       0.044772      0.002480         0.005596    7.997990e-04
# 29       0.259240      0.083935         0.014592    2.057893e-03
# 30       0.751338      0.171439         0.063761    1.459803e-02
# 31       2.760302      0.449958         0.187884    9.360738e-02
# 32       0.074153      0.029670         0.012594    1.019153e-03
# 33       0.114929      0.055926         0.016190    9.901378e-03
# 34       0.063760      0.016243         0.011593    1.198053e-03
# 35       0.091543      0.036154         0.014391    7.055393e-03
# 36       0.042173      0.001599         0.005397    4.899990e-04
# 37       0.170494      0.004269         0.012793    4.002336e-04
# 38       0.357580      0.018367         0.024585    1.355623e-03
# 39       2.297986      0.387796         0.175092    8.316712e-02
# 40       0.054166      0.026422         0.005597    7.994179e-04
# 41       0.180489      0.002938         0.012992    6.328630e-04
# 42       0.725954      0.289720         0.061162    2.262566e-02
# 43       2.300184      0.614803         0.109532    2.151546e-03
# 44       0.019188      0.008699         0.006996    2.681808e-03
# 45       0.041775      0.011764         0.010593    1.853885e-03
# 46       0.065359      0.058321         0.015191    1.148880e-02
# 47       0.035179      0.000981         0.009393    7.992758e-04
#
#    param_learning_rate   param_loss param_n_estimators  \
# 0                   10       linear                 10
# 1                   10       linear                 50
# 2                   10       linear                100
# 3                   10       linear                500
# 4                   10       square                 10
# 5                   10       square                 50
# 6                   10       square                100
# 7                   10       square                500
# 8                   10  exponential                 10
# 9                   10  exponential                 50
# 10                  10  exponential                100
# 11                  10  exponential                500
# 12                  50       linear                 10
# 13                  50       linear                 50
# 14                  50       linear                100
# 15                  50       linear                500
# 16                  50       square                 10
# 17                  50       square                 50
# 18                  50       square                100
# 19                  50       square                500
# 20                  50  exponential                 10
# 21                  50  exponential                 50
# 22                  50  exponential                100
# 23                  50  exponential                500
# 24                 100       linear                 10
# 25                 100       linear                 50
# 26                 100       linear                100
# 27                 100       linear                500
# 28                 100       square                 10
# 29                 100       square                 50
# 30                 100       square                100
# 31                 100       square                500
# 32                 100  exponential                 10
# 33                 100  exponential                 50
# 34                 100  exponential                100
# 35                 100  exponential                500
# 36                 500       linear                 10
# 37                 500       linear                 50
# 38                 500       linear                100
# 39                 500       linear                500
# 40                 500       square                 10
# 41                 500       square                 50
# 42                 500       square                100
# 43                 500       square                500
# 44                 500  exponential                 10
# 45                 500  exponential                 50
# 46                 500  exponential                100
# 47                 500  exponential                500
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -12.706837
# 1   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -14.013395
# 2   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -14.101388
# 3   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -13.990209
# 4   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.459315
# 5   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.559254
# 6   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.466447
# 7   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.485601
# 8   {'learning_rate': 10, 'loss': 'exponential', '...           0.000841
# 9   {'learning_rate': 10, 'loss': 'exponential', '...          -0.155705
# 10  {'learning_rate': 10, 'loss': 'exponential', '...          -1.354559
# 11  {'learning_rate': 10, 'loss': 'exponential', '...          -0.224867
# 12  {'learning_rate': 50, 'loss': 'linear', 'n_est...         -15.459315
# 13  {'learning_rate': 50, 'loss': 'linear', 'n_est...         -15.577398
# 14  {'learning_rate': 50, 'loss': 'linear', 'n_est...         -15.503745
# 15  {'learning_rate': 50, 'loss': 'linear', 'n_est...         -15.577398
# 16  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.206541
# 17  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.206541
# 18  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.206541
# 19  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.206541
# 20  {'learning_rate': 50, 'loss': 'exponential', '...         -15.112554
# 21  {'learning_rate': 50, 'loss': 'exponential', '...         -15.295341
# 22  {'learning_rate': 50, 'loss': 'exponential', '...         -15.173031
# 23  {'learning_rate': 50, 'loss': 'exponential', '...         -15.346479
# 24  {'learning_rate': 100, 'loss': 'linear', 'n_es...         -16.206541
# 25  {'learning_rate': 100, 'loss': 'linear', 'n_es...         -16.206541
# 26  {'learning_rate': 100, 'loss': 'linear', 'n_es...         -16.206541
# 27  {'learning_rate': 100, 'loss': 'linear', 'n_es...         -16.206541
# 28  {'learning_rate': 100, 'loss': 'square', 'n_es...          -1.185061
# 29  {'learning_rate': 100, 'loss': 'square', 'n_es...         -16.206541
# 30  {'learning_rate': 100, 'loss': 'square', 'n_es...         -16.206541
# 31  {'learning_rate': 100, 'loss': 'square', 'n_es...         -16.206541
# 32  {'learning_rate': 100, 'loss': 'exponential', ...          -8.345035
# 33  {'learning_rate': 100, 'loss': 'exponential', ...         -16.206541
# 34  {'learning_rate': 100, 'loss': 'exponential', ...          -8.330608
# 35  {'learning_rate': 100, 'loss': 'exponential', ...           0.572074
# 36  {'learning_rate': 500, 'loss': 'linear', 'n_es...         -16.206541
# 37  {'learning_rate': 500, 'loss': 'linear', 'n_es...         -16.206541
# 38  {'learning_rate': 500, 'loss': 'linear', 'n_es...         -16.206541
# 39  {'learning_rate': 500, 'loss': 'linear', 'n_es...         -16.206541
# 40  {'learning_rate': 500, 'loss': 'square', 'n_es...          -1.325542
# 41  {'learning_rate': 500, 'loss': 'square', 'n_es...         -16.206541
# 42  {'learning_rate': 500, 'loss': 'square', 'n_es...         -16.206541
# 43  {'learning_rate': 500, 'loss': 'square', 'n_es...         -16.206541
# 44  {'learning_rate': 500, 'loss': 'exponential', ...          -1.325542
# 45  {'learning_rate': 500, 'loss': 'exponential', ...          -1.325542
# 46  {'learning_rate': 500, 'loss': 'exponential', ...          -2.252831
# 47  {'learning_rate': 500, 'loss': 'exponential', ...         -15.459315
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -3.440918         -16.048683         -15.647681
# 1          -19.822681         -16.819201         -16.278613
# 2          -19.903071         -16.979860         -16.278613
# 3          -20.034141         -17.080116         -16.225950
# 4          -22.554858         -15.898123         -16.332654
# 5          -22.472564         -18.829096         -16.348148
# 6          -22.421156         -18.829096         -16.348148
# 7          -22.421156         -18.889500         -16.348148
# 8           -0.493203          -0.365212          -0.335370
# 9           -0.955032          -0.623318          -0.143971
# 10          -1.381549          -0.322555          -0.728259
# 11          -1.087729          -0.477645          -0.611628
# 12          -5.457476         -15.898123         -16.560974
# 13         -22.975756         -18.855182         -16.401365
# 14         -22.975756         -18.973279         -16.483922
# 15         -22.621030         -18.973279         -16.483922
# 16          -2.091413          -2.757254         -17.128714
# 17         -23.455127         -19.717638         -17.128714
# 18         -23.455127         -19.717638         -17.128714
# 19         -23.455127         -19.717638         -17.128714
# 20         -22.433323         -19.019164         -16.036810
# 21         -22.554858         -18.642249         -16.203091
# 22         -22.606266         -18.569254         -16.268266
# 23         -22.606266         -18.731122         -16.286998
# 24         -23.455127         -19.717638         -17.128714
# 25         -23.455127         -19.717638         -17.128714
# 26         -23.455127         -19.717638         -17.128714
# 27         -23.455127         -19.717638         -17.128714
# 28         -23.455127          -2.824444          -2.243017
# 29         -23.455127         -19.717638         -17.128714
# 30         -23.455127         -19.717638         -17.128714
# 31         -23.455127         -19.717638         -17.128714
# 32         -22.975756         -19.282007         -16.444398
# 33         -22.975756          -4.632309         -16.332654
# 34         -23.455127          -4.807269         -16.560974
# 35         -19.005662         -15.898123         -16.348148
# 36         -23.455127          -2.824444         -17.128714
# 37         -23.455127          -4.406545         -17.128714
# 38         -23.455127          -4.406545         -17.128714
# 39         -23.455127         -19.717638         -17.128714
# 40          -2.223166          -3.789230          -3.682168
# 41          -2.223166         -19.717638         -17.128714
# 42          -2.223166         -19.717638         -17.128714
# 43          -0.963014         -19.717638         -17.128714
# 44          -2.223166          -4.406545          -2.316631
# 45          -2.223166          -4.406545          -3.603851
# 46          -8.995972          -3.789230          -1.344924
# 47          -2.223166          -2.824444          -2.316631
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -10.218207       -11.612465        4.601712               13
# 1          -12.016851       -15.790148        2.643993               23
# 2          -12.353245       -15.923235        2.574715               24
# 3          -12.316626       -15.929408        2.648531               25
# 4          -12.019555       -16.452901        3.411682               27
# 5          -12.395788       -17.120970        3.374042               34
# 6          -12.214258       -17.055821        3.417571               30
# 7          -12.210555       -17.070992        3.423187               32
# 8            0.282586        -0.182072        0.283974                1
# 9           -0.840771        -0.543759        0.338853                2
# 10          -0.414605        -0.840305        0.451496                4
# 11          -0.377754        -0.555925        0.294411                3
# 12         -12.019555       -13.079089        4.121833               14
# 13         -12.823842       -17.326709        3.418775               36
# 14         -12.823842       -17.352109        3.433045               37
# 15         -12.823842       -17.295894        3.310060               35
# 16         -12.823842       -10.201553        6.513276               11
# 17         -12.823842       -17.866373        3.560552               38
# 18         -12.823842       -17.866373        3.560552               38
# 19         -12.823842       -17.866373        3.560552               38
# 20         -12.695325       -17.059435        3.364544               31
# 21         -12.524708       -17.044049        3.379731               29
# 22         -12.438247       -17.011013        3.422719               28
# 23         -12.549328       -17.104039        3.388919               33
# 24         -12.823842       -17.866373        3.560552               38
# 25         -12.823842       -17.866373        3.560552               38
# 26         -12.823842       -17.866373        3.560552               38
# 27         -12.823842       -17.866373        3.560552               38
# 28          -2.640214        -6.469573        8.511755               10
# 29         -12.823842       -17.866373        3.560552               38
# 30         -12.823842       -17.866373        3.560552               38
# 31         -12.823842       -17.866373        3.560552               38
# 32         -12.823842       -15.974207        5.065834               26
# 33         -12.695325       -14.568517        5.978529               20
# 34         -12.823842       -13.195564        6.492366               15
# 35          -2.089415       -10.553855        8.111734               12
# 36         -12.823842       -14.487734        6.769698               19
# 37         -12.823842       -14.804154        6.232841               21
# 38         -12.823842       -14.804154        6.232841               21
# 39         -12.823842       -17.866373        3.560552               38
# 40          -1.081177        -2.420257        1.139902                5
# 41         -12.823842       -13.619980        6.110715               17
# 42         -12.823842       -13.619980        6.110715               17
# 43         -12.823842       -13.367950        6.583281               16
# 44          -2.640214        -2.582420        1.010962                6
# 45          -1.882614        -2.688344        1.141331                7
# 46          -1.917598        -3.660111        2.788008                8
# 47          -1.882614        -4.941234        5.267683                9

# %%
'age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'
age=int(input("Enter the Age: "))
bmi=int(input("Enter the BMI_range: "))
children=int(input("Enter the Children_count: "))
sex_male=int(input("Enter the sex, male 1/female 0: "))
smoker_yes=int(input("Enter the smoker, yes 1/no 0): "))

pred=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Prediction is: {}".format(pred))
# Out:
# Enter the Age: 53
# Enter the BMI_range: 30
# Enter the Children_count: 2
# Enter the sex, male 1/female 0: 0
# Enter the smoker, yes 1/no 0): 0
# Prediction is: [35117.98576896]
