# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.20,random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
# x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
grid_params={"n_estimators": [10,50,100],
             "learning_rate": [10,50],
             "loss": ["linear","square","exponential"]
            }
grid=GridSearchCV(AdaBoostRegressor(),grid_params,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [10, 50],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
results=grid.cv_results_
print("The result is : {}".format(grid.best_params_))
# Out:
# The result is : {'learning_rate': 10, 'loss': 'exponential', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.067555      0.028411         0.011793        0.005228
# 1        0.386944      0.243472         0.029781        0.013474
# 2        0.991543      0.340430         0.058961        0.036925
# 3        0.044371      0.002244         0.007795        0.000400
# 4        0.183478      0.004406         0.015790        0.000400
# 5        0.381747      0.021904         0.030180        0.002480
# 6        0.047967      0.003096         0.009794        0.002637
# 7        0.297002      0.085760         0.025384        0.007909
# 8        0.840644      0.245629         0.076350        0.017601
# 9        0.109927      0.002827         0.020786        0.001166
# 10       0.213058      0.050564         0.015390        0.000489
# 11       0.346970      0.011831         0.027182        0.002134
# 12       0.043171      0.001165         0.007795        0.000400
# 13       0.185677      0.002225         0.016389        0.001853
# 14       0.371153      0.006148         0.029781        0.003761
# 15       0.045169      0.001938         0.008395        0.001356
# 16       0.323586      0.115971         0.033379        0.011596
# 17       0.794273      0.217940         0.053165        0.022643
#
#    param_learning_rate   param_loss param_n_estimators  \
# 0                   10       linear                 10
# 1                   10       linear                 50
# 2                   10       linear                100
# 3                   10       square                 10
# 4                   10       square                 50
# 5                   10       square                100
# 6                   10  exponential                 10
# 7                   10  exponential                 50
# 8                   10  exponential                100
# 9                   50       linear                 10
# 10                  50       linear                 50
# 11                  50       linear                100
# 12                  50       square                 10
# 13                  50       square                 50
# 14                  50       square                100
# 15                  50  exponential                 10
# 16                  50  exponential                 50
# 17                  50  exponential                100
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -14.491511
# 1   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -13.287943
# 2   {'learning_rate': 10, 'loss': 'linear', 'n_est...         -13.809691
# 3   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.432234
# 4   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.442881
# 5   {'learning_rate': 10, 'loss': 'square', 'n_est...         -15.442881
# 6   {'learning_rate': 10, 'loss': 'exponential', '...          -1.037779
# 7   {'learning_rate': 10, 'loss': 'exponential', '...          -0.306713
# 8   {'learning_rate': 10, 'loss': 'exponential', '...          -0.615315
# 9   {'learning_rate': 50, 'loss': 'linear', 'n_est...         -14.429869
# 10  {'learning_rate': 50, 'loss': 'linear', 'n_est...         -15.566874
# 11  {'learning_rate': 50, 'loss': 'linear', 'n_est...         -15.579966
# 12  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.183327
# 13  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.183327
# 14  {'learning_rate': 50, 'loss': 'square', 'n_est...         -16.183327
# 15  {'learning_rate': 50, 'loss': 'exponential', '...         -15.121767
# 16  {'learning_rate': 50, 'loss': 'exponential', '...         -15.420796
# 17  {'learning_rate': 50, 'loss': 'exponential', '...         -15.268301
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0          -15.370676         -14.844713         -12.970047
# 1          -17.034134         -15.053851         -14.804528
# 2          -17.260100         -15.060895         -14.847050
# 3           -3.070811         -16.835578         -16.340913
# 4          -18.912369         -16.835578         -16.309910
# 5          -18.912369         -16.835578         -16.309910
# 6           -2.055768          -0.538270          -1.772735
# 7           -0.422418          -1.258470          -0.083582
# 8           -0.740335          -0.718445          -0.077624
# 9          -17.483765         -16.835578         -16.300792
# 10         -18.934675         -16.835578         -16.393642
# 11         -18.949727         -16.835578         -16.424644
# 12         -19.807532         -16.835578         -17.090549
# 13         -19.807532         -16.835578         -17.090549
# 14         -19.807532         -16.835578         -17.090549
# 15         -18.898504         -16.046570         -13.744331
# 16         -18.506198         -16.046570         -16.083583
# 17         -18.764883         -16.046570         -16.057755
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -13.541687       -14.243727        0.872664                5
# 1          -11.936367       -14.423365        1.722397                6
# 2          -12.948445       -14.785236        1.451223                7
# 3          -13.435807       -13.023069        5.110091                4
# 4          -16.706560       -16.841460        1.144156               12
# 5          -16.706560       -16.841460        1.144156               12
# 6            0.391332        -1.002644        0.878881                3
# 7           -0.814182        -0.577073        0.414986                2
# 8           -0.261492        -0.482642        0.265540                1
# 9          -16.706560       -16.351313        1.033214               10
# 10         -16.706560       -16.887466        1.114837               14
# 11         -16.706560       -16.899295        1.114576               15
# 12         -16.706560       -17.324709        1.276194               16
# 13         -16.706560       -17.324709        1.276194               16
# 14         -16.706560       -17.324709        1.276194               16
# 15         -16.706560       -16.103546        1.715135                8
# 16         -15.476037       -16.306637        1.134025                9
# 17         -16.706560       -16.568814        1.188861               11

# %%
'age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'
age=int(input("Enter the Age: "))
bmi=int(input("Enter the BMI_range: "))
children=int(input("Enter the Children_count: "))
sex_male=int(input("Enter the sex, male 1/female 0: "))
smoker_yes=int(input("Enter the smoker, yes 1/no 0): "))

pred=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Prediction is: {}".format(pred))
# Out:
# Enter the Age: 23
# Enter the BMI_range: 23
# Enter the Children_count: 1
# Enter the sex, male 1/female 0: 0
# Enter the smoker, yes 1/no 0): 1
# Prediction is: [30779.31971333]
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
