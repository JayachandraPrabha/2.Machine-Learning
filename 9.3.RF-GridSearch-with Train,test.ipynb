# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
grid_params={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
             'n_estimators':[10,50,100,500],
             'max_features':['None','sqrt','log2','auto']
            }
grid=GridSearchCV(RandomForestRegressor(),grid_params,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 80 fits failed out of a total of 320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'auto' (deprecated), 'log2', 'sqrt'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 48 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'auto' (deprecated), 'sqrt', 'log2'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.79957783 0.8158871
#  0.81396135 0.81802214 0.79734629 0.81393425 0.81555126 0.81737623
#  0.79457699 0.80906409 0.80628736 0.81031858        nan        nan
#         nan        nan 0.80254355 0.81485525 0.8143612  0.81798985
#  0.7967648  0.81674622 0.81606581 0.81712251 0.79579508 0.80910458
#  0.80886667 0.80954044        nan        nan        nan        nan
#  0.79302121 0.8122227  0.81487528 0.81682838 0.8025178  0.81499279
#  0.81811321 0.81810839 0.79236914 0.80566105 0.80368547 0.80310919
#         nan        nan        nan        nan 0.80559072 0.81862721
#  0.81665881 0.81700059 0.79419127 0.81193959 0.81557963 0.81745805
#  0.80422987 0.80341086 0.80890272 0.81147994]
#   warnings.warn(
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['None', 'sqrt', 'log2', 'auto'],
#                          'n_estimators': [10, 50, 100, 500]},
#              verbose=3)

# %%
result=grid.cv_results_
# result
print("result is {}".format(grid.best_params_))
# Out:
# result is {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 50}

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001400      0.000488         0.000000        0.000000
# 1        0.002998      0.001788         0.000000        0.000000
# 2        0.002196      0.001166         0.000000        0.000000
# 3        0.003198      0.003427         0.000000        0.000000
# 4        0.067956      0.008289         0.006797        0.000748
# ..            ...           ...              ...             ...
# 59       4.335731      0.568162         0.219466        0.081545
# 60       0.252242      0.034944         0.014592        0.001742
# 61       0.546062      0.262524         0.020588        0.008588
# 62       1.403934      0.443392         0.041776        0.018658
# 63       5.680503      0.355882         0.191683        0.079524
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 10
# 1    squared_error               None                 50
# 2    squared_error               None                100
# 3    squared_error               None                500
# 4    squared_error               sqrt                 10
# ..             ...                ...                ...
# 59         poisson               log2                500
# 60         poisson               auto                 10
# 61         poisson               auto                 50
# 62         poisson               auto                100
# 63         poisson               auto                500
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...                NaN
# 3   {'criterion': 'squared_error', 'max_features':...                NaN
# 4   {'criterion': 'squared_error', 'max_features':...           0.828114
# ..                                                ...                ...
# 59  {'criterion': 'poisson', 'max_features': 'log2...           0.848405
# 60  {'criterion': 'poisson', 'max_features': 'auto...           0.836259
# 61  {'criterion': 'poisson', 'max_features': 'auto...           0.841972
# 62  {'criterion': 'poisson', 'max_features': 'auto...           0.847874
# 63  {'criterion': 'poisson', 'max_features': 'auto...           0.851737
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4            0.791489           0.775174           0.830955
# ..                ...                ...                ...
# 59           0.826708           0.804328           0.838560
# 60           0.818000           0.784972           0.815618
# 61           0.814972           0.801544           0.795723
# 62           0.817826           0.797137           0.814945
# 63           0.821940           0.799037           0.815721
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               49
# 1                 NaN              NaN             NaN               49
# 2                 NaN              NaN             NaN               49
# 3                 NaN              NaN             NaN               49
# 4            0.772157         0.799578        0.025345               41
# ..                ...              ...             ...              ...
# 59           0.769290         0.817458        0.028217                6
# 60           0.766301         0.804230        0.025118               35
# 61           0.762844         0.803411        0.025803               37
# 62           0.766730         0.808903        0.026653               30
# 63           0.768965         0.811480        0.027241               25
#
# [64 rows x 16 columns]

# %%
'age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'
age=int(input("Enter the Age: "))
bmi=int(input("Enter the BMI_range: "))
children=int(input("Enter the Children_count: "))
sex_male=int(input("Enter the sex, male 1/female 0: "))
smoker_yes=int(input("Enter the smoker, yes 1/no 0): "))

pred=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Prediction is: {}".format(pred))
# Out:
# Enter the Age: 23
# Enter the BMI_range: 25
# Enter the Children_count: 2
# Enter the sex, male 1/female 0: 1
# Enter the smoker, yes 1/no 0): 1
# Prediction is: [46846.8301322]
