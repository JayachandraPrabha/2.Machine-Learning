# %% [markdown]
# SVM = Support Vector Machine
# Steps:
#     1) Data collection
#         import pandas as pd
#     2) Data Preprocessing
#         i) If Nominal--> One hot encoding (pd.get_dummies(variable,drop_first=True))
#         ii) If Ordinal--> Mapping--> Label encoding
#     3) Input & output split
#         i/p variable=variable[["-","-",...]]
#         o/p variable=variable[["-","-",...]]
#     4) Train & test split
#         from sklearn.model_selection import train_test_split
#     5) Considering train set
#         i) If needed apply standardization to (x_train & x_test)
#         from sklearn.preprocessing import StandardScaler
#     6) Model Creation
#         from sklearn.Linear_model/svm import LinearRegression/SVR
#     7) Selection of best model by applying different algorithms to the model
#         i) Simple Linear Regression algorithm
#         ii) Multiple Linear Regression algorithm
#         iii) SVM
#         iv) DT
#         v) RF, etc
#     8) Find predicted value(y_predict) by applying into x_test
#     9) Apply y_predict to y_test
#     10) Find r2_score value (analyze whwther the value is nearing (0 or 1)
#     from sklearn.metrics import r2_score
#     11) Finalize the best model
#     12) Save the model in a file as binary format
#     13) Give input & see the result & deploy it

# %%
import pandas as pd

# %%
dataset=pd.read_csv("50_Startups.csv")
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]

# %%
dependent=dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.35006454, -0.78547109,  0.1011968 ,  1.73205081, -0.73379939],
#        [-0.55530319, -1.48117426,  0.02734979, -0.57735027,  1.36277029],
#        [ 0.07935762,  0.80133381, -0.55152132,  1.73205081, -0.73379939],
#        [-0.54638238,  1.32505817,  0.07011684, -0.57735027, -0.73379939],
#        [ 0.43485371, -0.35598663,  0.75148516,  1.73205081, -0.73379939],
#        [ 1.26943143,  0.85518519,  0.98603118,  1.73205081, -0.73379939],
#        [ 1.04525007,  1.28077047,  0.4404    ,  1.73205081, -0.73379939],
#        [-1.529843  ,  0.02942065, -1.6218751 , -0.57735027,  1.36277029],
#        [-1.53976251, -2.76767264, -1.6372965 , -0.57735027,  1.36277029],
#        [-0.13115188,  1.14497701, -0.76949991, -0.57735027,  1.36277029],
#        [ 0.92791613, -0.02992062,  0.48303162, -0.57735027,  1.36277029],
#        [-0.20932933, -0.2993768 , -0.89915412,  1.73205081, -0.73379939],
#        [-0.17870828,  0.2251352 , -1.26401642, -0.57735027, -0.73379939],
# ...

# %%
x_test
# Out:
# array([[-0.1214952 ,  2.2889053 , -0.68032287,  1.73205081, -0.73379939],
#        [ 0.6280306 , -1.22069499,  0.38557774, -0.57735027, -0.73379939],
#        [ 0.65490061, -0.49434195,  0.21885524,  1.73205081, -0.73379939],
#        [-0.94762148, -1.49417936, -0.30512104,  1.73205081, -0.73379939],
#        [ 1.77048111, -0.85932667,  1.6668808 ,  1.73205081, -0.73379939],
#        [ 0.00961775,  0.17279112,  1.22341229, -0.57735027,  1.36277029],
#        [-1.11353109, -2.21896176, -0.13669119, -0.57735027,  1.36277029],
#        [-0.22790703,  1.13222416, -0.92274884, -0.57735027,  1.36277029],
#        [ 0.05047007, -0.02351175,  0.81952074,  1.73205081, -0.73379939],
#        [ 1.52509853, -1.23610162,  1.32858469,  1.73205081, -0.73379939]])

# %%
from sklearn.svm import SVR
regressor=SVR(kernel="linear",C=1000)
regressor.fit(x_train, y_train)
# Out:
# C:\Users\jayac\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1000, kernel='linear')

# %%
y_predict=regressor.predict(x_test)
y_predict
# Out:
# array([106326.92103228, 123104.34034876, 123244.0822852 ,  83023.55784889,
#        158799.82821258, 123862.18150654,  81601.61897116, 101007.56059925,
#        118015.12147478, 149562.788621  ])

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test, y_predict)
r_score
# Out:
# 0.7849121652938659
